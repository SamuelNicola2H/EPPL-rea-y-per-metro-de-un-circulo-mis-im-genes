# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelNicola2H/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/El_profe_Circulo_Samuel_Nicola_0106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Samuel Nicola NL = 40 Fecha 25/Mar/2026: ✈
# ---
# # Calcular Area y perimetro de un circulo: ⭕
# ---
# #![Logo de Markdown](https://raw.githubusercontent.com/SamuelNicola2H/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/circulo.area.perimetro.PNG)
#
# ---
# ## Formula para Calcular el area
# # $ A=π*r^2 $
# ---
# ## Formula para calcular el perimetro
# # $P=2*π*r$
# ---
# ## Datos de entrada
# # $r$ ?
# ---
# ## Diagrama de flujo Lucidchart
# #![Logo de Markdown](https://raw.githubusercontent.com/SamuelNicola2H/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/DF%20Area%20perimetro%20Circulo.png)

# %%
# Calcular Area y Perimetro de un circulo
# Variables A, P, r
# Formulas A = pi * r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular Area y Perimetro de un circulo")
r = float(input("Ingrese el valor del radio: "))
A = math.pi * r**2
P = 2 * math.pi * r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Samuel Nicola NL = 40")
# Out:
# Calcular Area y Perimetro de un circulo
# Ingrese el valor del radio: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Samuel Nicola NL = 40

# %% [markdown]
# # Relacion entre codigos y diagrama DF en Tldraw
# # ![Logo de Markdown](https://raw.githubusercontent.com/SamuelNicola2H/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/Tldraw%20DF%20y%20Codigo.png)
